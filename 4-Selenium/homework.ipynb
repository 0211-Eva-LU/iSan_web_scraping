# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager

# 建立 Service 物件，指定 chromedriver.exe 的路徑


# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://www.momoshop.com.tw/main/Main.jsp")

# %%
search_but=driver.find_element(By.CSS_SELECTOR,".mx-auto.flex.w-content.flex-wrap input")

# %%
search_but.send_keys("衛生紙")

# %%
driver.find_element(By.CSS_SELECTOR,".mx-auto.flex.w-content.flex-wrap button").click()

# %%
search_allname=driver.find_elements(By.CSS_SELECTOR,".listAreaUl .listAreaLi .prdNameTitle h3")

# %%
for name in search_allname:
    p_name = name.text
    print(p_name)
# Out:
# 【得意】連續抽取式花紋衛生紙100抽/84包
# 【倍潔雅】花漾柔感抽取式衛生紙PEFC(150抽x84包/箱)
# 【倍潔雅】舒感柔韌抽取式衛生紙PEFC(150抽x70包/箱)
# 【櫻花】超值新柔感抽取式衛生紙(150抽x84包/箱)
# 【朵舒】棉仔紙超厚柔抽取式衛生紙(150抽x84包/箱)
# 【朵舒】momoco舒適柔韌抽取式衛生紙(150抽x80包/箱)
# 【舒潔xmomo獨家】熱銷霸王抽取衛生紙110抽x60包/*2箱
# 【Kirkland Signature 科克蘭】三層抽取式衛生紙(120抽x72包)
# 【春風】抽取式衛生紙-輕柔膚觸-100抽*24包*3串
# 【東京豪德寺xmomo獨家】招財貓日式抽取式衛生紙(150抽x100包/箱)
# 【Kleenex 舒潔】絲絨舒膚抽取衛生紙110抽x60包/箱
# 【Kirkland Signature 科克蘭】三層抽取式衛生紙(120抽x24包)
# 【朵舒】棉仔紙厚柔抽取式衛生紙(150抽x72包/箱)
# 【倍潔雅】柔軟舒適抽取式衛生紙(150抽56包/箱)
# 【唯潔雅】潔淨柔感抽取式衛生紙(100抽12包6袋/箱)
# 【Kirkland Signature 科克蘭】三層抽取衛生紙 120抽 X 72入 免運
# 【櫻花】超值新柔感抽取式衛生紙(150抽x84包/*2箱)
# 【Superpure 極度淳】淨柔感抽取式花紋衛生紙150抽x84包/箱
# 【得意重裝版】抽取式花紋衛生紙(150抽*84包)
# 【Super Do極度朵朵】抽取式萬用紙巾150抽84包/箱
# 【倍潔雅】花漾柔感抽取式衛生紙200抽x48包/箱
# 【MAY FLOWER 五月花】新柔韌抽取式衛生紙(110抽x72包)
# 【春風】輕柔細緻抽取式衛生紙(100抽80入/箱)
# 【得意】連續抽取式花紋衛生紙(100抽*84包)
# 【MAY FLOWER 五月花】厚棒抽取式衛生紙(90抽x60包)
# UNIDESIGN 新柔感衛生紙(110抽*80包)
# 【Livi 優活】抽取式衛生紙(100抽10包6袋/箱)
# 【春風】超細柔抽取式衛生紙 110抽*72包/箱
# 【東京豪德寺xmomo獨家】招財貓開運抽取式衛生紙(150抽x96包/箱)
# 【MAY FLOWER 五月花】新柔韌抽取式衛生紙(130抽x48包)
