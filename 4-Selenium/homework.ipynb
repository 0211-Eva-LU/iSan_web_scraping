# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager

# 建立 Service 物件，指定 chromedriver.exe 的路徑


# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://www.momoshop.com.tw/main/Main.jsp")
time.sleep(3)

# %%
search_but=driver.find_element(By.CSS_SELECTOR,".mx-auto.flex.w-content.flex-wrap input")

# %%
search_but.send_keys("stanley保溫杯")

# %%
driver.find_element(By.CSS_SELECTOR,".ml-0.mt-0.box-border.flex.h-[120px].w-[569px].flex-col.items-center.justify-center.pt-[25px] button").click()
# Out:
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 driver.find_element(By.CSS_SELECTOR,".ml-0.mt-0.box-border.flex.h-[120px].w-[569px].flex-col.items-center.justify-center.pt-[25px] button").click()
#
# File c:\Users\student\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webdriver.py:926, in WebDriver.find_element(self, by, value)
#     923         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     924     return elements[0]
# --> 926 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\student\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webdriver.py:458, in WebDriver.execute(self, driver_command, params)
#     455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
# --> 458     self.error_handler.check_response(response)
#     459     response["value"] = self._unwrap_value(response.get("value", None))
#     460     return response
#
# File c:\Users\student\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:233, in ErrorHandler.check_response(self, response)
#     231         alert_text = value["alert"].get("text")
#     232     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 233 raise exception_class(message, screen, stacktrace)
#
# InvalidSelectorException: Message: invalid selector: An invalid or illegal selector was specified
#   (Session info: chrome=142.0.7444.163); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidselectorexception
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x7ff68389a235
# 	0x7ff6835f2630
# 	0x7ff6833816dd
# 	0x7ff6833894c8
# 	0x7ff68338c52f
# 	0x7ff68338c5ef
# 	0x7ff6833d9b27
# 	0x7ff6833da58c
# 	0x7ff68342ed77
# 	0x7ff68342baba
# 	0x7ff6833cb0ed
# 	0x7ff6833cbf63
# 	0x7ff6838c5d60
# 	0x7ff6838bfe8a
# 	0x7ff6838e1005
# 	0x7ff68360d71e
# 	0x7ff683614e1f
# 	0x7ff6835fb7c4
# 	0x7ff6835fb97f
# 	0x7ff6835e18e8
# 	0x7ffd58767374
# 	0x7ffd59c7cc91

# %%
driver.find_element(By.CSS_SELECTOR,".mx-auto.flex.w-content.flex-wrap button").click()

# %%
search_all=driver.find_elements(By.CSS_SELECTOR,".listAreaUl .listAreaLi")
search_name=driver.find_element(By.CSS_SELECTOR,".prdNameTitle h3")
search_price=driver.find_element(By.CSS_SELECTOR,".price")
search_url=driver.find_element(By.CSS_SELECTOR, ".goodsUrl").get_attribute("href")
search_src=driver.find_element(By.CSS_SELECTOR,'picture')

# %%
search_all=driver.find_elements(By.CSS_SELECTOR,".listAreaUl .listAreaLi")
for p in search_all:
    p_name = p.find_element(By.CSS_SELECTOR,".prdNameTitle h3").text
    p_price = p.find_element(By.CSS_SELECTOR,".price").text
    p_url=p.find_element(By.CSS_SELECTOR, ".goodsUrl a").get_attribute("href")
    p_img=p.find_element(By.CSS_SELECTOR,'.prdImg').get_attribute("src")
    

    print(p_img)
# Out:
# https://i1.momoshop.com.tw/1719378052/goodsimg/0012/980/194/12980194_OR_m.webp
# https://i2.momoshop.com.tw/1719378093/goodsimg/0012/980/203/12980203_OR_m.webp
# https://i2.momoshop.com.tw/1692481216/goodsimg/0011/171/062/11171062_OR_m.webp
# https://i6.momoshop.com.tw/1749532854/goodsimg/TP000/0273/0000/211/TP00002730000211_O.webp
# https://i6.momoshop.com.tw/1749532854/goodsimg/TP000/0273/0000/617/TP00002730000617_O.webp
# https://i2.momoshop.com.tw/1761888068/goodsimg/0013/738/266/13738266_OR_m.webp
# https://i7.momoshop.com.tw/1749532854/goodsimg/TP000/0273/0000/520/TP00002730000520_O.webp
# https://i1.momoshop.com.tw/1755252496/goodsimg/0014/345/871/14345871_OR_m.webp
# https://i5.momoshop.com.tw/1749532854/goodsimg/TP000/0273/0000/166/TP00002730000166_O.webp
# https://i3.momoshop.com.tw/1719378052/goodsimg/0012/980/195/12980195_OR_m.webp
# https://i5.momoshop.com.tw/1749532854/goodsimg/TP000/0273/0000/519/TP00002730000519_O.webp
# https://i2.momoshop.com.tw/1692476047/goodsimg/0011/130/108/11130108_OR_m.webp
# https://i6.momoshop.com.tw/1750937678/goodsimg/TP000/0273/0000/651/TP00002730000651_O.webp
# https://i3.momoshop.com.tw/1719378093/goodsimg/0012/980/202/12980202_OR_m.webp
# https://i5.momoshop.com.tw/1749532854/goodsimg/TP000/0273/0000/156/TP00002730000156_O_m.jpg
# https://i3.momoshop.com.tw/1692393970/goodsimg/0010/650/322/10650322_OR_m.webp
# https://i3.momoshop.com.tw/1692481197/goodsimg/0011/171/059/11171059_OR_m.webp
# https://i4.momoshop.com.tw/1761896313/goodsimg/0014/054/447/14054447_OR_m.webp
# https://i2.momoshop.com.tw/1692475858/goodsimg/0011/129/955/11129955_OR_m.webp
# https://i4.momoshop.com.tw/1692475843/goodsimg/0011/130/106/11130106_OR_m.webp
# https://i3.momoshop.com.tw/1692480472/goodsimg/0011/165/448/11165448_OR_m.webp
# https://i4.momoshop.com.tw/1692480502/goodsimg/0011/165/450/11165450_OR_m.webp
# https://i4.momoshop.com.tw/1692480463/goodsimg/0011/165/455/11165455_OR_m.webp
# https://i4.momoshop.com.tw/1692480447/goodsimg/0011/165/449/11165449_OR_m.webp
# https://i3.momoshop.com.tw/1692475845/goodsimg/0011/129/953/11129953_OR_m.webp
# https://i1.momoshop.com.tw/1692480532/goodsimg/0011/165/453/11165453_OR_m.webp
# https://i1.momoshop.com.tw/1692480473/goodsimg/0011/165/454/11165454_OR_m.webp
# https://i4.momoshop.com.tw/1692475868/goodsimg/0011/129/954/11129954_OR_m.webp
# https://i1.momoshop.com.tw/1692480379/goodsimg/0011/165/452/11165452_OR_m.webp
# https://i7.momoshop.com.tw/1752307688/goodsimg/TP000/1165/0000/210/TP00011650000210_O_m.jpg

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
driver.find_element(By.CSS_SELECTOR,".page-control .page-btn.page-next a").click()
# search_page = driver.find_element(By.CSS_SELECTOR,".page-control")
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# Cell In[20], line 2
#       1 driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
# ----> 2 driver.find_element(By.CSS_SELECTOR,".page-control .page-btn.page-next a").click()
#       3 # search_page = driver.find_element(By.CSS_SELECTOR,".page-control")
#
# File c:\Users\student\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webelement.py:119, in WebElement.click(self)
#     111 def click(self) -> None:
#     112     """Clicks the element.
#     113
#     114     Example:
#    (...)    117     >>> element.click()
#     118     """
# --> 119     self._execute(Command.CLICK_ELEMENT)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webelement.py:572, in WebElement._execute(self, command, params)
#     570     params = {}
#     571 params["id"] = self._id
# --> 572 return self._parent.execute(command, params)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webdriver.py:458, in WebDriver.execute(self, driver_command, params)
#     455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
# --> 458     self.error_handler.check_response(response)
#     459     response["value"] = self._unwrap_value(response.get("value", None))
#     460     return response
#
# File c:\Users\student\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:233, in ErrorHandler.check_response(self, response)
#     231         alert_text = value["alert"].get("text")
#     232     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 233 raise exception_class(message, screen, stacktrace)
#
# ElementClickInterceptedException: Message: element click intercepted: Element <a>...</a> is not clickable at point (1259, 7). Other element would receive the click: <li class="checkoutBtn">...</li>
#   (Session info: chrome=142.0.7444.163); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#elementclickinterceptedexception
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x7ff68389a235
# 	0x7ff6835f2630
# 	0x7ff6833816dd
# 	0x7ff6833e24c9
# 	0x7ff6833dfe4e
# 	0x7ff6833dcd71
# 	0x7ff6833dbc10
# 	0x7ff6833cd3a8
# 	0x7ff683402b0a
# 	0x7ff6833ccc36
# 	0x7ff68342baba
# 	0x7ff6833cb0ed
# 	0x7ff6833cbf63
# 	0x7ff6838c5d60
# 	0x7ff6838bfe8a
# 	0x7ff6838e1005
# 	0x7ff68360d71e
# 	0x7ff683614e1f
# 	0x7ff6835fb7c4
# 	0x7ff6835fb97f
# 	0x7ff6835e18e8
# 	0x7ffd58767374
# 	0x7ffd59c7cc91

# %%
page_number=int(driver.find_element(By.CSS_SELECTOR,".page-control .page-number").text.split('/')[-1])

# %%
search_page = driver.find_element(By.CSS_SELECTOR,".page-control")
cnt = 0
while 0 < page_number:
    for p in search_all:
        p_name = p.find_element(By.CSS_SELECTOR,".prdNameTitle h3").text
        p_price = p.find_element(By.CSS_SELECTOR,".price").text
        p_url=p.find_element(By.CSS_SELECTOR, ".goodsUrl a").get_attribute("href")
        p_img=p.find_element(By.CSS_SELECTOR,'.prdImg').get_attribute("src")
        

        print(p_name,p_price,p_url,p_img)
        time.sleep(5)
        search_page.find_element(By.CSS_SELECTOR,".page-btn.page-next").click()
        cnt+=1
# Out:
# 【Stanley】官方直營 經典系列 IceFlow 手提吸管杯2.0 0.88L(全色系) 1,380 https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=13837630&Area=search&mdiv=403&oid=1_1&cid=index&kw=stanley%E4%BF%9D%E6%BA%AB%E6%9D%AF https://i2.momoshop.com.tw/1753506121/goodsimg/0013/837/630/13837630_OR_m.webp
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# Cell In[15], line 13
#      11 print(p_name,p_price,p_url,p_img)
#      12 time.sleep(5)
# ---> 13 search_page.find_element(By.CSS_SELECTOR,".page-btn.page-next").click()
#      14 cnt+=1
#
# File c:\Users\student\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webelement.py:119, in WebElement.click(self)
#     111 def click(self) -> None:
#     112     """Clicks the element.
#     113
#     114     Example:
#    (...)    117     >>> element.click()
#     118     """
# --> 119     self._execute(Command.CLICK_ELEMENT)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webelement.py:572, in WebElement._execute(self, command, params)
#     570     params = {}
#     571 params["id"] = self._id
# --> 572 return self._parent.execute(command, params)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webdriver.py:458, in WebDriver.execute(self, driver_command, params)
#     455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
# --> 458     self.error_handler.check_response(response)
#     459     response["value"] = self._unwrap_value(response.get("value", None))
#     460     return response
#
# File c:\Users\student\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:233, in ErrorHandler.check_response(self, response)
#     231         alert_text = value["alert"].get("text")
#     232     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 233 raise exception_class(message, screen, stacktrace)
#
# ElementClickInterceptedException: Message: element click intercepted: Element <div class="page-btn page-next">...</div> is not clickable at point (1536, 12). Other element would receive the click: <a class=" activeBtn" title="登記活動" href="https://www.momoshop.com.tw/mypage/MemberCenter.jsp?func=18&amp;cid=memfu&amp;oid=login&amp;ctype=B&amp;mdiv=1000100000-bt_0_003_01&amp;_=1685432891447">...</a>
#   (Session info: chrome=142.0.7444.163); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#elementclickinterceptedexception
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x7ff68389a235
# 	0x7ff6835f2630
# 	0x7ff6833816dd
# 	0x7ff6833e24c9
# 	0x7ff6833dfe4e
# 	0x7ff6833dcd71
# 	0x7ff6833dbc10
# 	0x7ff6833cd3a8
# 	0x7ff683402b0a
# 	0x7ff6833ccc36
# 	0x7ff68342baba
# 	0x7ff6833cb0ed
# 	0x7ff6833cbf63
# 	0x7ff6838c5d60
# 	0x7ff6838bfe8a
# 	0x7ff6838e1005
# 	0x7ff68360d71e
# 	0x7ff683614e1f
# 	0x7ff6835fb7c4
# 	0x7ff6835fb97f
# 	0x7ff6835e18e8
# 	0x7ffd58767374
# 	0x7ffd59c7cc91
