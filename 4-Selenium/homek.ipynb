# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager

# 建立 Service 物件，指定 chromedriver.exe 的路徑


# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://online.carrefour.com.tw/")
time.sleep(3)

# %%
product_info = []
def get_all_product(name):
    search_but=driver.find_element(By.CSS_SELECTOR,".logo-search.fleft input")
    search_but.send_keys(name)
    driver.find_element(By.CSS_SELECTOR,"#search").click()
    search_all=driver.find_elements(By.CSS_SELECTOR,".hot-recommend.clearfix .hot-recommend-item.line")
    
    for product in search_all:
        product_name = product.find_element(By.CSS_SELECTOR,".box-img a").get_attribute("data-name")
        product_price = product.find_element(By.CSS_SELECTOR,".box-img a").get_attribute("data-price")
        product_url = product.find_element(By.CSS_SELECTOR,".box-img a").get_attribute("href")
        product_img = product.find_element(By.CSS_SELECTOR,".box-img .m_lazyload").get_attribute("src")
        
        product_info.append({
            "product_name": product_name,
            "product_price":product_price,
            "product_url":product_url,
            "product_img": product_img
        })

# %%
search_all=driver.find_elements(By.CSS_SELECTOR,".hot-recommend.clearfix .hot-recommend-item.line")
p_name=search_all[0].find_element(By.CSS_SELECTOR,".box-img a").get_attribute("data-name")
p_url=search_all[0].find_element(By.CSS_SELECTOR,".box-img a").get_attribute("href")
p_price=search_all[0].find_element(By.CSS_SELECTOR,".box-img a").get_attribute("data-price")
p_img=search_all[0].find_element(By.CSS_SELECTOR,".box-img .m_lazyload").get_attribute("src")
print(p_name,p_url,p_price,p_img)
# Out:
# 品客原味口味洋芋片102g https://online.carrefour.com.tw/zh/%E5%93%81%E5%AE%A2/1402011800101.html 59.0 https://online.carrefour.com.tw/dw/image/v2/BFHC_PRD/on/demandware.static/-/Sites-carrefour-tw-m-inner/default/dw5e9d6c26/images/large/1402011800101.png?sw=300&bgcolor=FFFFFF

# %%
next_btn = driver.find_element(By.CSS_SELECTOR, ".pagenation img[alt='next']")
next_btn.click()

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager

# 建立 Service 物件，指定 chromedriver.exe 的路徑


# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://online.carrefour.com.tw/")
time.sleep(3)
