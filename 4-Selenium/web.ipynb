# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager

# 建立 Service 物件，指定 chromedriver.exe 的路徑


# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://today.line.me/tw/v2/movie/incinemas/playing")

#爬購物網站
#打包成function(物品名稱):
#回傳圖片url、詳細物品名稱、價格、購買連結、錯誤樣態

# %%
import time

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight)") #運用JS script滑至底部
time.sleep(3)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager

# 建立 Service 物件，指定 chromedriver.exe 的路徑


# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://today.line.me/tw/v2/movie/incinemas/playing")

movie_list=driver.find_elements(By.CSS_SELECTOR,".detailListItem.movieListing-movie")

driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
time.sleep(5)

# last_movie= movie_list[-1]
# print(f'目前數量:{len(movie_list)}')
# while True:
#     driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
#     time.sleep(2)
#     movie_list = driver.find_elements(By.CSS_SELECTOR,".detailListItem.movieListing-movie")
#     if last_movie == movie_list[-1]:
#         break

# last_movie = movie_list[-1]
# print(f'目前數量:{len(movie_list)}')

all_movie_info = []
for movie in movie_list :
    movie_name=movie.find_element(By.CSS_SELECTOR,".detailListItem-titles").text
    movie_grad=movie.find_element(By.CSS_SELECTOR,".iconInfo.detailListItem-iconInfo").text
    movie_time=movie.find_element(By.CSS_SELECTOR,".detailListItem-status>span").text
    movie_link=movie.find_element(By.CSS_SELECTOR,".detailListItem-bookingButton").get_attribute("href")

    all_movie_info.append({
        "name":movie_name,
        "average_grade":movie_grad,
        "time": movie_time,
        "link":movie_link}
    )

print(all_movie_info)
# Out:
# [{'name': '出神入化3\nNow You See Me：Now You Don’t', 'average_grade': '6.2', 'time': '• 1小時53分 • 2025年11月14日上映', 'link': 'https://today.line.me/tw/v3/movie/JPMx3ox/1'}, {'name': '逃亡遊戲\nThe Running Man', 'average_grade': '7.5', 'time': '• 2小時13分 • 2025年11月12日上映', 'link': 'https://today.line.me/tw/v3/movie/9mllw13/1'}, {'name': '終極戰士：殺戮星球\nPredator: Badlands', 'average_grade': '9.0', 'time': '• 1小時47分 • 2025年11月06日上映', 'link': 'https://today.line.me/tw/v3/movie/5y7K1gV/1'}, {'name': '劇場版 咒術迴戰 澀谷事變 x 死滅迴游 先行上映\nJUJUTSU KAISEN: Execution -Shibuya Incident×The Culling Game Begins-', 'average_grade': '10', 'time': '• 1小時28分 • 2025年11月14日上映', 'link': 'https://today.line.me/tw/v3/movie/zNk3rOK/1'}, {'name': '劇場版『鏈鋸人 蕾潔篇』\nChainsaw Man – The Movie: Reze Arc', 'average_grade': '9.1', 'time': '• 1小時40分 • 2025年09月24日上映', 'link': 'https://today.line.me/tw/v3/movie/qo9
年11月07日上映', 'link': 'https://today.line.me/tw/v3/movie/XYwJD89/1'}, {'name': '去死吧，親愛的\nDie My Love', 'average_grade': '8.6', 'time': '• 1小時58分 • 2025年11月07日上映', 'link': 'https://today.line.me/tw/v3/movie/7Nz3Qyk/1'}, {'name': '左撇子女孩\nLeft-Handed Girl', 'average_grade': '7.4', 'time': '• 1小時48分 • 2025年10月31日上映', 'link': 'https://today.line.me/tw/v3/movie/vXV0ZM0/1'}, {'name': '女孩\nGirl', 'average_grade': '8.5', 'time': '• 2小時04分 • 2025年10月31日上映', 'link': 'https://today.line.me/tw/v3/movie/PGNny9o/1'}, {'name': '鬼聲泣3\nTee Yod 3', 'average_grade': '8.3', 'time': '• 1小時44分 • 2025年10月31日上映', 'link': 'https://today.line.me/tw/v3/movie/eLOOzwK/1'}, {'name': 'G-DRAGON IN CINEMA [Übermensch]\nG-DRAGON IN CINEMA [Übermensch]', 'average_grade': '9.6', 'time': '• 1小時46分 • 2025年10月29日上映', 'link': 'https://today.line.me/tw/v3/movie/JPO827q/1'}]

# %%
print(movie_list[-1].find_element(By.CSS_SELECTOR,".detailListItem-titles").text)
print(movie_list[-1].find_element(By.CSS_SELECTOR,".iconInfo.detailListItem-iconInfo").text)
print(movie_list[-1].find_element(By.CSS_SELECTOR,".detailListItem-status>span").text)
print(movie_list[-1].find_element(By.CSS_SELECTOR,".detailListItem-bookingButton").get_attribute("href"))
# Out:
# G-DRAGON IN CINEMA [Übermensch]
# G-DRAGON IN CINEMA [Übermensch]
# 9.6
# • 1小時46分 • 2025年10月29日上映
# https://today.line.me/tw/v3/movie/JPO827q/1

# %%
all_movie_info = []
for movie in movie_list :
    movie_name=movie.find_element(By.CSS_SELECTOR,".detailListItem-titles").text
    movie_grad=movie.find_element(By.CSS_SELECTOR,".iconInfo.detailListItem-iconInfo").text
    movie_time=movie.find_element(By.CSS_SELECTOR,".detailListItem-status>span").text
    movie_link=movie.find_element(By.CSS_SELECTOR,".detailListItem-bookingButton").get_attribute("href")

    all_movie_info.append({
        "name":movie_name,
        "average_grade":movie_grad,
        "time": movie_time,
        "link":movie_link}
    )
print(len(all_movie_info))
print(all_movie_info)
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In[77], line 3
#       1 all_movie_info = []
#       2 for movie in movie_list :
# ----> 3     movie_name=movie.find_element(By.CSS_SELECTOR,".detailListItem-titles").text
#       4     movie_grad=movie.find_element(By.CSS_SELECTOR,".iconInfo.detailListItem-iconInfo").text
#       5     movie_time=movie.find_element(By.CSS_SELECTOR,".detailListItem-status>span").text
#
# File c:\Users\student\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webelement.py:601, in WebElement.find_element(self, by, value)
#     575 """Find an element given a By strategy and locator.
#     576
#     577 Parameters:
#    (...)    598     The first matching `WebElement` found on the page.
#     599 """
#     600 by, value = self._parent.locator_converter.convert(by, value)
# --> 601 return self._execute(Command.FIND_CHILD_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\student\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webelement.py:572, in WebElement._execute(self, command, params)
#     570     params = {}
#     571 params["id"] = self._id
# --> 572 return self._parent.execute(command, params)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webdriver.py:458, in WebDriver.execute(self, driver_command, params)
#     455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
# --> 458     self.error_handler.check_response(response)
#     459     response["value"] = self._unwrap_value(response.get("value", None))
#     460     return response
#
# File c:\Users\student\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:233, in ErrorHandler.check_response(self, response)
#     231         alert_text = value["alert"].get("text")
#     232     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 233 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: stale element not found
#   (Session info: chrome=142.0.7444.163); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#staleelementreferenceexception
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x7ff69cbfa235
# 	0x7ff69c952630
# 	0x7ff69c6e16dd
# 	0x7ff69c6f8175
# 	0x7ff69c6f6c63
# 	0x7ff69c6ea168
# 	0x7ff69c6e805c
# 	0x7ff69c6ec52f
# 	0x7ff69c6ec5ef
# 	0x7ff69c739b27
# 	0x7ff69c73a58c
# 	0x7ff69c72cd7c
# 	0x7ff69c72cc36
# 	0x7ff69c78baba
# 	0x7ff69c72b0ed
# 	0x7ff69c72bf63
# 	0x7ff69cc25d60
# 	0x7ff69cc1fe8a
# 	0x7ff69cc41005
# 	0x7ff69c96d71e
# 	0x7ff69c974e1f
# 	0x7ff69c95b7c4
# 	0x7ff69c95b97f
# 	0x7ff69c9418e8
# 	0x7ffd58767374
# 	0x7ffd59c7cc91

# %%
driver.get(all_movie_info[0]['link'])
driver.find_element(By.CSS_SELECTOR,"ul.tabs-list.movie li:nth-child(3)").click()
time.sleep(2)

# %%
names = driver.find_elements(By.CSS_SELECTOR,".css-hnvcda .ratingCommentItemUser")
print(names[0].text)
Days = driver.find_elements(By.CSS_SELECTOR,".css-hnvcda .ratingCommentItemUser-createdTime.css-squ0i5")
print(Days[0].text)
contents = driver.find_elements(By.CSS_SELECTOR,".css-hnvcda .ratingCommentItemContent")
print(contents[0].text)
# Out:
# 菲力
# 11月14日22:45
# 不能說不好看，只是略感失望，舊騎士在整場戲有點多餘，幾乎沒給他們發揮的空間，讓人懷疑導演跟編劇刻意在賣情懷，殘酷一點的說，感覺像是新騎士踩著舊騎士的肩膀上位@@

# %%
start_mapping={"M12 18.344l-5.81 3.609c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17.077.032.138.094.17.17l2.684 6.514 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343z":2,

"M12.12 2.024c.076.031.137.093.169.17l2.684 6.513 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343l-5.81 3.61c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17zM12 6.463v9.651l3.662 2.275-.925-4.383 3.316-3.086-4.398-.443L12 6.463z":1,

"M12.12 2.024c.076.031.137.093.169.17l2.684 6.513 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343l-5.81 3.61c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17zm1.6 8.365L12 6.216l-1.72 4.173-4.549.458 3.43 3.191-.961 4.546 3.8-2.36 3.799 2.36-.96-4.546 3.429-3.191-4.548-.458z":0}

# %%
cnt = 0
rating_container=driver.find_element(By.CSS_SELECTOR,".css-hnvcda .ratingCommentItemUser-ratingContainer")
stars=driver.find_elements(By.CSS_SELECTOR,".css-hnvcda .ratingStar path")
grade = 0
    for star in stars:
        path_d = star.get_attribute('d')
        grade += start_mapping[path_d]
        cnt +=1

    if cnt>3:
        break
    

print(grade)
# Out:
# 5

# %%
start_mapping={"M12 18.344l-5.81 3.609c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17.077.032.138.094.17.17l2.684 6.514 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343z":2,

"M12.12 2.024c.076.031.137.093.169.17l2.684 6.513 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343l-5.81 3.61c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17zM12 6.463v9.651l3.662 2.275-.925-4.383 3.316-3.086-4.398-.443L12 6.463z":1,

"M12.12 2.024c.076.031.137.093.169.17l2.684 6.513 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343l-5.81 3.61c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17zm1.6 8.365L12 6.216l-1.72 4.173-4.549.458 3.43 3.191-.961 4.546 3.8-2.36 3.799 2.36-.96-4.546 3.429-3.191-4.548-.458z":0}


def get_all_comment(url):
    driver.get(url)
    driver.find_element(By.CSS_SELECTOR,"ul.tabs-list.movie li:nth-child(3)").click()
    time.sleep(2)
    comment_info = []
    comment_cards=driver.find_elements(By.CSS_SELECTOR,".css-hnvcda")
    movie_name=driver.find_element(By.CSS_SELECTOR,".title.header.css-ybyea6").text
    for comment_card in comment_cards:
        comment_user = comment_card.find_element(By.CSS_SELECTOR,".ratingCommentItemUser").text
        comment_date=comment_card.find_element(By.CSS_SELECTOR,".ratingCommentItemUser-createdTime.css-squ0i5").text
        comment=comment_card.find_element(By.CSS_SELECTOR,".ratingCommentItemContent").text
        stars=comment_card.find_elements(By.CSS_SELECTOR,".ratingStar path")
        
        grade = 0
        for star in stars:
            path_d = star.get_attribute('d')
            grade += start_mapping[path_d]


        comment_info.append({
            "comment_user":comment_user,
            "grade":grade,
            "comment_date":comment_date,
            "comment":comment
        })

        
    return (movie_name,comment_info)

# %%
allcomment=get_all_comment(all_movie_info[0]['link'])
print(allcomment)
# Out:
# ('出神入化3', [{'comment_user': '菲力', 'grade': 5, 'comment_date': '11月14日22:45', 'comment': '不能說不好看，只是略感失望，舊騎士在整場戲有點多餘，幾乎沒給他們發揮的空間，讓人懷疑導演跟編劇刻意在賣情懷，殘酷一點的說，感覺像是新騎士踩著舊騎士的肩膀上位@@'}, {'comment_user': 'Syuan🐟', 'grade': 9, 'comment_date': '11月15日11:04', 'comment': '有種要新舊交替的感覺，但...我還是喜歡原本的五騎士\n9分給我喜歡的五騎士'}, {'comment_user': 'kkkww Liu', 'grade': 6, 'comment_date': '11月15日18:04', 'comment': '要推新人來讓ip走遠不反對，可是跟前二集比劇情松散魔術情結都輸前二集太多，真有第四集不會再進電影院觀看了'}, {'comment_user': '凱鑫企業/玉龍跆拳道 葉佳欣(John)', 'grade': 5, 'comment_date': '1天前', 'comment': '普普 小失望'}, {'comment_user': 'WU', 'grade': 8, 'comment_date': '2天前', 'comment': '好看 邏輯交代滿清楚的 劇情新穎'}, {'comment_user': 'Wayne', 'grade': 7, 'comment_date': '2天前', 'comment': '還可以，劇情算是交代的滿清楚的\n帶出新成員'}, {'comment_user': '昱凱', 'grade': 4, 'comment_date': '2天前', 'comment': '真的是很難看的續集\n我也是很欣賞原先的5人組合\n但這些知名的5人只在頭尾組合\n中間讓這些新人擔任主角\n我一度在電影院內睡著\n真的不知道編劇為何要做這樣的安排\n很無言💤'}, {'comment_user': '雯 ꗯ̤̮ ꗯ꙼̈', 'grade': 5, 'comment_date': '11月15日01:46', 'comment': '略失望'}, {'comment_user': '沛公', 'grade': 7, 'comment_date': '1天前', 'comment': '為續作鋪陳，尚可。'}, {'comment_user': '🐶葶🐈\u200d⬛', 'grade': 5, 'comment_date': '2天前', 'comment': '嗯⋯真的覺得還好，蠻失望的⋯沒有前兩部精彩'}, {'comment_user': '快乐天堂🇦🇷', 'grade': 8, 'comment_date': '6小時前', 'comment': '長江後浪推前浪'}, {'comment_user': 'James', 'grade': 3, 'comment_date': '13小時前', 'comment': '第一集 滿新鮮感 不錯看⋯第二⋯覺得普普⋯⋯第三就不會想去看⋯⋯ㄞ'}, {'comment_user': '陶知☃️', 'grade': 3, 'comment_date': '20小時前', 'comment': '很失望的續集，幾乎舊騎士只是配角的感覺\n出事都是他們扛⋯新騎士內容佔據了大半\n唉再有續集也不會進電影看了'}, {'comment_user': '❤︎獅獅☻', 'grade': 7, 'comment_date': '1天前', 'comment': '劇情普普 有點老梗 但整體來說還是可以。'}, {'comment_user': 'David Chen', 'grade': 7, 'comment_date': '2天前', 'comment': '雖說舊班底有點老化，但還是比新人有魅力'}, {'comment_user': '賴彥廷', 'grade': 10, 'comment_date': '11月14日15:50', 'comment': '好看，有點像是老騎士帶新騎士的感覺'}])
